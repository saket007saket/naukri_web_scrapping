# %%
import time
from selenium import webdriver
import pandas as pd

# %%
PATH = "C:\Program Files (x86)\chromedriver.exe"

# %%
driver = webdriver.Chrome(PATH)

# %%
jobs={"Roles_for_applicant":[],
     "Companies_name":[],
     "Location_of_job":[],
     "Experience":[],
     "Skills_set_required":[],
     "Salary_offered":[],
     "Description_about_job":[]}

# %%
def get_url(position):
  template ="https://www.naukri.com/"
  pos=''
  p=position.lower()
  p=p.split()
  for i in p:
    pos= pos+i+'-'
  pos=pos+'jobs'+'-'

  template=template+pos+'?'+'k={}'
  url=template.format(position.lower())
  url1=url.split('?')
  url_final=url1[0]+'{}?'+url1[1]
  return url_final

# %%
url=get_url('Data Scientist')
url
# Out:
# 'https://www.naukri.com/data-scientist-jobs-{}?k=data scientist'

# %%
for i in range(167,728):
    driver.get(url.format(i))
    time.sleep(3)
    lst=driver.find_elements_by_css_selector(".jobTuple.bgWhite.br4.mb-8")
    for job in lst:
        driver.implicitly_wait(10)
        role=job.find_element_by_css_selector("a.title.fw500.ellipsis").text
        company_name=job.find_element_by_css_selector("a.subTitle.ellipsis.fleft").text
        location_of_job=job.find_element_by_css_selector(".fleft.grey-text.br2.placeHolderLi.location").text
        exp=job.find_element_by_css_selector(".ellipsis.fleft.fs12.lh16").text
        skills=job.find_element_by_css_selector(".tags.has-description").text
        salary=job.find_element_by_css_selector(".fleft.grey-text.br2.placeHolderLi.salary").text
        job_desc=job.find_element_by_css_selector(".job-description.fs12.grey-text").text
        jobs["Roles_for_applicant"].append(role)
        jobs["Companies_name"].append(company_name)
        jobs["Location_of_job"].append(location_of_job)
        jobs["Experience"].append(exp)
        jobs["Skills_set_required"].append(skills)
        jobs["Salary_offered"].append(salary)
        jobs["Description_about_job"].append(job_desc)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-8792b84fe883> in <module>
#       1 for i in range(167,728):
#       2     driver.get(url.format(i))
# ----> 3     time.sleep(3)
#       4     lst=driver.find_elements_by_css_selector(".jobTuple.bgWhite.br4.mb-8")
#       5     for job in lst:
#
# KeyboardInterrupt:

# %%
df=pd.DataFrame(jobs)
df
# Out:
#                                   Roles_for_applicant  \
# 0              Practice Lead- Artificial Intelligence
# 1           Database Administrator Required in Canada
# 2                                  Research Associate
# 3                                 Front-end Developer
# 4                     Product Manager(Software Sales)
# ..                                                ...
# 75                                     Data Scientist
# 76                                  Sr Data Scientist
# 77              Sr Solution Architect- Data Scientist
# 78                        Looking For Data Scientists
# 79  Assistant Manager/ Manager/ Data Scientist - P...
#
#                              Companies_name  \
# 0               Converge Staffing Solutions
# 1           Pleco Migration Private Limited
# 2                           Era IT Solution
# 3                   Bigshyft Hiring for ORI
# 4                           Nore Consulting
# ...

# %%
df["Skills_set_required"]=list(df["Skills_set_required"].str.split('\n'))
df
# Out:
#                                   Roles_for_applicant  \
# 0              Practice Lead- Artificial Intelligence
# 1           Database Administrator Required in Canada
# 2                                  Research Associate
# 3                                 Front-end Developer
# 4                     Product Manager(Software Sales)
# ..                                                ...
# 75                                     Data Scientist
# 76                                  Sr Data Scientist
# 77              Sr Solution Architect- Data Scientist
# 78                        Looking For Data Scientists
# 79  Assistant Manager/ Manager/ Data Scientist - P...
#
#                              Companies_name  \
# 0               Converge Staffing Solutions
# 1           Pleco Migration Private Limited
# 2                           Era IT Solution
# 3                   Bigshyft Hiring for ORI
# 4                           Nore Consulting
# ...

# %%
#df.to_csv('file11.csv',index=False)

# %%
df1=pd.read_csv(r"C:\Users\sak\Documents\file2.csv")
df2=pd.read_csv(r"C:\Users\sak\Documents\file3.csv")
df3=pd.read_csv(r"C:\Users\sak\Documents\file4.csv")
df4=pd.read_csv(r"C:\Users\sak\Documents\file5.csv")
df5=pd.read_csv(r"C:\Users\sak\Documents\file6.csv")
df6=pd.read_csv(r"C:\Users\sak\Documents\file7.csv")
df7=pd.read_csv(r"C:\Users\sak\Documents\file8.csv")
df8=pd.read_csv(r"C:\Users\sak\Documents\file9.csv")
df9=pd.read_csv(r"C:\Users\sak\Documents\file10.csv")
df10=pd.read_csv(r"C:\Users\sak\Documents\file11.csv")
frames=[df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]
data_scientist_jobs=pd.concat(frames)

# %%
data_scientist_jobs
# Out:
#                                   Roles_for_applicant  \
# 0   Data Scientist/Analyst - Machine Learning/Deep...
# 1                    Data Scientist, Machine Learning
# 2              Data Scientist/Analyst – IT Department
# 3                                   Data Scientist, I
# 4            Explore job openings on Data Scientist!!
# ..                                                ...
# 75                                     Data Scientist
# 76                                  Sr Data Scientist
# 77              Sr Solution Architect- Data Scientist
# 78                        Looking For Data Scientists
# 79  Assistant Manager/ Manager/ Data Scientist - P...
#
#                              Companies_name  \
# 0                                 EchoIndia
# 1                     Fractal Analytics Ltd
# 2                      Nandan Denim Limited
# 3                      iXplore Technologies
# 4                 Bristlecone India Limited
# ...

# %%
data_scientist_jobs.to_csv('data_scientist_jobs.csv',index=False)

# %%
data=pd.read_csv(r"C:\Users\sak\Documents\data_scientist_jobs.csv")
data
# Out:
#                                      Roles_for_applicant  \
# 0      Data Scientist/Analyst - Machine Learning/Deep...
# 1                       Data Scientist, Machine Learning
# 2                 Data Scientist/Analyst – IT Department
# 3                                      Data Scientist, I
# 4               Explore job openings on Data Scientist!!
# ...                                                  ...
# 14433                                     Data Scientist
# 14434                                  Sr Data Scientist
# 14435              Sr Solution Architect- Data Scientist
# 14436                        Looking For Data Scientists
# 14437  Assistant Manager/ Manager/ Data Scientist - P...
#
#                                 Companies_name  \
# 0                                    EchoIndia
# 1                        Fractal Analytics Ltd
# 2                         Nandan Denim Limited
# 3                         iXplore Technologies
# ...

# %%
data.Description_about_job[1]
# Out:
# 'Experience of working on end-to-end data science pipeline: problem scoping, data gather...'
